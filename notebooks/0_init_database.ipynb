# %% [markdown]
# # Initialize the database containing museums and cities data
#
# This notebook loads museums data from wikipedia, and cities data from GeoNames

# %% [markdown]
# ## 1. Import Required Libraries and Modules
# We start by importing the necessary libraries and the custom modules from the museums_db package.

# %%
import sys
import os

import museums_db
import pandas as pd

from pprint import pprint

# Configure database connection based on environment
if os.environ.get("JUPYTER_CONTAINER"):
    # Running inside Docker container
    os.environ["DB_HOST"] = "db"
else:
    # Running locally
    os.environ["DB_HOST"] = "localhost"

# %% [markdown]
# ## 2. Initialize Database
# Set up the MySQL database and tables 'museums' and 'cities'.

# %%
# Initialize the database
museums_db.init_db()

# %% [markdown]
# ## 3. Retrieve and Store Museum Data
# Fetch the list of museums with more than 2 million annual visitors from Wikipedia and store them in the database.

# %%
df_museums = museums_db.get_most_visited_museums()
print(f"Loaded {len(df_museums)} museums")
df_museums.head()

museums_db.insert_museums_data(df_museums)
# Out:
# Key WIKIMEDIA_API_KEY not found in .env.
# Loaded 53 museums
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/mysql/connector/connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate entry 'Louvre-Paris-France' for key 'museums.name'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[3], line 5
#       2 print(f"Loaded {len(df_museums)} museums")
#       3 df_museums.head()
# ----> 5 museums_db.insert_museums_data(df_museums)
#
# File /app/museums_db/db.py:63, in insert_museums_data(df)
#      59     museums.append((row["name"], row["city"], row["country"], row["annual_visitors"]))
#      61 # TODO: prevoir IntegrityError: 1062 (23000): Duplicate entry 'Paris-France' for key 'cities.name'
# ---> 63 cursor.executemany(query, museums)
#      64 conn.commit()
#      65 cursor.close()
#
# File /usr/local/lib/python3.12/site-packages/mysql/connector/cursor_cext.py:473, in CMySQLCursor.executemany(self, operation, seq_params)
#     471     if stmt is not None:
#     472         self._executed = stmt
# --> 473         return self.execute(cast(str, stmt))
#     475 rowcnt = 0
#     476 try:
#     477     # When processing read ops (e.g., SELECT), rowcnt is updated
#     478     # based on self._rowcount. For write ops (e.g., INSERT) is
#     479     # updated based on self._affected_rows.
#     480     # The variable self._description is None for write ops, that's
#     481     # why we use it as indicator for updating rowcnt.
#
# File /usr/local/lib/python3.12/site-packages/mysql/connector/cursor_cext.py:353, in CMySQLCursor.execute(self, operation, params, map_results)
#     345 self._executed = (
#     346     self._stmt_partition["single_stmts"].popleft()
#     347     if map_results
#     348     else self._stmt_partition["mappable_stmt"]
#     349 )
#     351 try:
#     352     self._handle_result(
# --> 353         self._connection.cmd_query(
#     354             self._stmt_partition["mappable_stmt"],
#     355             raw=self._raw,
#     356             buffered=self._buffered,
#     357             raw_as_string=self._raw_as_string,
#     358         )
#     359     )
#     360 except MySQLInterfaceError as err:
#     361     if hasattr(err, "errno"):
#
# File /usr/local/lib/python3.12/site-packages/mysql/connector/opentelemetry/context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File /usr/local/lib/python3.12/site-packages/mysql/connector/connection_cext.py:781, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     779 except MySQLInterfaceError as err:
#     780     if hasattr(err, "errno"):
# --> 781         raise get_mysql_exception(
#     782             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     783         ) from err
#     784     raise InterfaceError(str(err)) from err
#     785 except AttributeError as err:
#
# IntegrityError: 1062 (23000): Duplicate entry 'Louvre-Paris-France' for key 'museums.name'

# %% [markdown]
# ## 4. Retrieve and Store City Population Data
# For each city, retrieve its population and store it in the database.

# %%
df_cities_countries = museums_db.extract_cities_and_countries(df_museums)
museums_db.get_cities_population(df_cities_countries)
df_cities_countries.head()

museums_db.insert_cities_data(df_cities_countries)

# %% [markdown]
# ## 5. Show data stored in database

# %%
museum_city_data: list[dict] = museums_db.get_museum_city_data()
df_select_data = pd.json_normalize(museum_city_data)

print(f"Loaded {len(df_select_data)} museum-city entries")

df_select_data.head()
